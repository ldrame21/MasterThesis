# %%
import pandas as pd

# %%
try:
    df = pd.read_csv('v20240401_v2_csv.csv', error_bad_lines=False, warn_bad_lines=True, sep=';')
except Exception as e:
    print(f"An error occurred: {e}")
# Out:
# /opt/anaconda3/envs/ada/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3441: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version.
#
#
#   exec(code_obj, self.user_global_ns, self.user_ns)
# /opt/anaconda3/envs/ada/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3441: FutureWarning: The warn_bad_lines argument has been deprecated and will be removed in a future version.
#
#
#   exec(code_obj, self.user_global_ns, self.user_ns)
# /opt/anaconda3/envs/ada/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3441: DtypeWarning: Columns (11,13,14,15,22,23) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
df.columns = [
    'Building_admission_date',  # Pand_opnamedatum
    'Building_admission_type',  # Pand_opnametype
    'Building_status',  # Pand_status
    'Building_calculation_type',  # Pand_berekeningstype
    'Building_energy_index',  # Pand_energieindex
    'Building_energy_class',  # Pand_energieklasse
    'Building_energy_label_is_private',  # Pand_energielabel_is_prive
    'Building_based_on_reference_building',  # Pand_is_op_basis_van_referentie_gebouw
    'Building_class',  # Pand_gebouwklasse
    'Measurement_valid_until',  # Meting_geldig_tot
    'Building_registration_date',  # Pand_registratiedatum
    'Building_postcode',  # Pand_postcode
    'Building_house_number',  # Pand_huisnummer
    'Building_house_letter',  # Pand_huisletter
    'Building_house_number_addition',  # Pand_huisnummertoevoeging
    'Building_detail_designation',  # Pand_detailaanduiding
    'Building_bag_residence_object_id',  # Pand_bagverblijfsobjectid
    'Building_bag_mooring_place_id',  # Pand_bagligplaatsid
    'Building_bag_standing_place_id',  # Pand_bagstandplaatsid
    'Building_bag_building_id',  # Pand_bagpandid
    'Building_type',  # Pand_gebouwtype
    'Building_subtype',  # Pand_gebouwsubtype
    'Building_project_name',  # Pand_projectnaam
    'Building_project_object',  # Pand_projectobject
    'Building_SBI_code',  # Pand_SBIcode
    'Building_usable_floor_area_thermal_zone',  # Pand_gebruiksoppervlakte_thermische_zone
    'Building_energy_requirement',  # Pand_energiebehoefte
    'Building_requirement_energy_requirement',  # Pand_eis_energiebehoefte
    'Building_primary_fossil_energy',  # Pand_primaire_fossiele_energie
    'Building_requirement_primary_fossil_energy',  # Pand_eis_primaire_fossiele_energie
    'Building_primary_fossil_energy_EMG_standard',  # Pand_primaire_fossiele_energie_EMG_forfaitair
    'Building_share_renewable_energy',  # Pand_aandeel_hernieuwbare_energie
    'Building_requirement_share_renewable_energy',  # Pand_eis_aandeel_hernieuwbare_energie
    'Building_share_renewable_energy_EMG_standard',  # Pand_aandeel_hernieuwbare_energie_EMG_forfaitair
    'Building_temperature_exceedance',  # Pand_temperatuuroverschrijding
    'Building_requirement_temperature_exceedance',  # Pand_eis_temperatuuroverschrijding
    'Building_heat_demand',  # Pand_warmtebehoefte LDD
    'Building_energy_index_with_EMG_standard'  # Pand_energieindex_met_EMG_forfaitair
]

# %%
'''df = df[['Building_energy_class',
    'Building_postcode',
    'Building_house_number', 
    'Building_house_letter', 
    'Building_house_number_addition',  
    'Building_detail_designation',
    'Building_bag_residence_object_id',
    'Building_bag_mooring_place_id',
    'Building_bag_standing_place_id',
    'Building_bag_building_id',
    'Building_type',
    'Building_subtype',
    'Building_SBI_code']]'''
# Out:
# "df = df[['Building_energy_class',\n    'Building_postcode',\n    'Building_house_number', \n    'Building_house_letter', \n    'Building_house_number_addition',  \n    'Building_detail_designation',\n    'Building_bag_residence_object_id',\n    'Building_bag_mooring_place_id',\n    'Building_bag_standing_place_id',\n    'Building_bag_building_id',\n    'Building_type',\n    'Building_subtype',\n    'Building_SBI_code']]"

# %%
df.shape
# Out:
# (5573516, 38)

# %%
df[df['Building_postcode'].notnull()].head()
# Out:
#         Building_admission_date Building_admission_type Building_status  \
# 269217                 20211007             Basisopname        Bestaand
# 269218                 20220512             Basisopname        Bestaand
# 269219                 20220512             Basisopname        Bestaand
# 269220                 20220512             Basisopname        Bestaand
# 269221                 20220512             Basisopname        Bestaand
#
#                          Building_calculation_type  Building_energy_index  \
# 269217  NTA 8800:2020 (basisopname utiliteitsbouw)                    NaN
# 269218      NTA 8800:2022 (basisopname woningbouw)                    NaN
# 269219      NTA 8800:2022 (basisopname woningbouw)                    NaN
# 269220      NTA 8800:2022 (basisopname woningbouw)                    NaN
# 269221      NTA 8800:2022 (basisopname woningbouw)                    NaN
#
#        Building_energy_class  Building_energy_label_is_private  \
# 269217                     C                               NaN
# 269218                   A++                               NaN
# 269219                   A++                               NaN
# 269220                   A++                               NaN
# 269221                  A+++                               NaN
#
#         Building_based_on_reference_building Building_class  \
# 269217                                     0              U
# 269218                                     0              W
# 269219                                     0              W
# 269220                                     0              W
# 269221                                     0              W
#
#         Measurement_valid_until  ...  Building_primary_fossil_energy  \
# 269217                 20311007  ...                          220.06
# 269218                 20320512  ...                           55.98
# 269219                 20320512  ...                           56.83
# 269220                 20320512  ...                           56.88
# 269221                 20320512  ...                           28.53
#
#        Building_requirement_primary_fossil_energy  \
# 269217                                        NaN
# 269218                                        NaN
# 269219                                        NaN
# 269220                                        NaN
# 269221                                        NaN
#
#         Building_primary_fossil_energy_EMG_standard  \
# 269217                                       220.06
# 269218                                        55.98
# 269219                                        56.83
# 269220                                        56.88
# 269221                                        28.53
#
#        Building_share_renewable_energy  \
# 269217                             0.0
# 269218                            54.0
# 269219                            55.4
# 269220                            54.8
# 269221                            81.0
#
#        Building_requirement_share_renewable_energy  \
# 269217                                         NaN
# 269218                                         NaN
# 269219                                         NaN
# 269220                                         NaN
# 269221                                         NaN
#
#        Building_share_renewable_energy_EMG_standard  \
# 269217                                          0.0
# 269218                                          NaN
# 269219                                          NaN
# 269220                                          NaN
# 269221                                          NaN
#
#         Building_temperature_exceedance  \
# 269217                              0.0
# 269218                              0.0
# 269219                              0.0
# 269220                              0.0
# 269221                              0.0
#
#         Building_requirement_temperature_exceedance  Building_heat_demand  \
# 269217                                          NaN                112.11
# 269218                                          NaN                 44.16
# 269219                                          NaN                 46.42
# 269220                                          NaN                 47.03
# 269221                                          NaN                 68.95
#
#         Building_energy_index_with_EMG_standard
# 269217                                      NaN
# 269218                                      NaN
# 269219                                      NaN
# 269220                                      NaN
# 269221                                      NaN
#
# [5 rows x 38 columns]

# %%
amsterdam_df = df[df['Building_postcode'].astype(str).str.match(r'10[0-9]{2}')]

# %%
amsterdam_df
# Out:
#         Building_admission_date Building_admission_type Building_status  \
# 269217                 20211007             Basisopname        Bestaand
# 269218                 20220512             Basisopname        Bestaand
# 269219                 20220512             Basisopname        Bestaand
# 269220                 20220512             Basisopname        Bestaand
# 269221                 20220512             Basisopname        Bestaand
# ...                         ...                     ...             ...
# 583830                 20170105                     NaN             NaN
# 583831                 20170105                     NaN             NaN
# 583832                 20170105                     NaN             NaN
# 583833                 20170105                     NaN             NaN
# 583834                 20170105                     NaN             NaN
#
#                                 Building_calculation_type  \
# 269217         NTA 8800:2020 (basisopname utiliteitsbouw)
# 269218             NTA 8800:2022 (basisopname woningbouw)
# 269219             NTA 8800:2022 (basisopname woningbouw)
# 269220             NTA 8800:2022 (basisopname woningbouw)
# 269221             NTA 8800:2022 (basisopname woningbouw)
# ...                                                   ...
# 583830  Nader Voorschrift, versie 1.0, 1 februari 2014...
# 583831  Nader Voorschrift, versie 1.0, 1 februari 2014...
# 583832  Nader Voorschrift, versie 1.0, 1 februari 2014...
# 583833  Nader Voorschrift, versie 1.0, 1 februari 2014...
# 583834  Nader Voorschrift, versie 1.0, 1 februari 2014...
#
#         Building_energy_index Building_energy_class  \
# 269217                    NaN                     C
# 269218                    NaN                   A++
# 269219                    NaN                   A++
# 269220                    NaN                   A++
# 269221                    NaN                  A+++
# ...                       ...                   ...
# 583830                   1.15                     A
# 583831                   1.15                     A
# 583832                   1.15                     A
# 583833                   1.15                     A
# 583834                   1.28                     A
#
#         Building_energy_label_is_private  \
# 269217                               NaN
# 269218                               NaN
# 269219                               NaN
# 269220                               NaN
# 269221                               NaN
# ...                                  ...
# 583830                               NaN
# 583831                               NaN
# 583832                               NaN
# 583833                               NaN
# 583834                               NaN
#
#         Building_based_on_reference_building Building_class  \
# 269217                                     0              U
# 269218                                     0              W
# 269219                                     0              W
# 269220                                     0              W
# 269221                                     0              W
# ...                                      ...            ...
# 583830                                     0              W
# 583831                                     0              W
# 583832                                     0              W
# 583833                                     0              W
# 583834                                     0              W
#
#         Measurement_valid_until  ...  Building_primary_fossil_energy  \
# 269217                 20311007  ...                          220.06
# 269218                 20320512  ...                           55.98
# 269219                 20320512  ...                           56.83
# 269220                 20320512  ...                           56.88
# 269221                 20320512  ...                           28.53
# ...                         ...  ...                             ...
# 583830                 20270105  ...                             NaN
# 583831                 20270105  ...                             NaN
# 583832                 20270105  ...                             NaN
# 583833                 20270105  ...                             NaN
# 583834                 20270105  ...                             NaN
#
#        Building_requirement_primary_fossil_energy  \
# 269217                                        NaN
# 269218                                        NaN
# 269219                                        NaN
# 269220                                        NaN
# 269221                                        NaN
# ...                                           ...
# 583830                                        NaN
# 583831                                        NaN
# 583832                                        NaN
# 583833                                        NaN
# 583834                                        NaN
#
#         Building_primary_fossil_energy_EMG_standard  \
# 269217                                       220.06
# 269218                                        55.98
# 269219                                        56.83
# 269220                                        56.88
# 269221                                        28.53
# ...                                             ...
# 583830                                          NaN
# 583831                                          NaN
# 583832                                          NaN
# 583833                                          NaN
# 583834                                          NaN
#
#        Building_share_renewable_energy  \
# 269217                             0.0
# 269218                            54.0
# 269219                            55.4
# 269220                            54.8
# 269221                            81.0
# ...                                ...
# 583830                             NaN
# 583831                             NaN
# 583832                             NaN
# 583833                             NaN
# 583834                             NaN
#
#        Building_requirement_share_renewable_energy  \
# 269217                                         NaN
# 269218                                         NaN
# 269219                                         NaN
# 269220                                         NaN
# 269221                                         NaN
# ...                                            ...
# 583830                                         NaN
# 583831                                         NaN
# 583832                                         NaN
# 583833                                         NaN
# 583834                                         NaN
#
#        Building_share_renewable_energy_EMG_standard  \
# 269217                                          0.0
# 269218                                          NaN
# 269219                                          NaN
# 269220                                          NaN
# 269221                                          NaN
# ...                                             ...
# 583830                                          NaN
# 583831                                          NaN
# 583832                                          NaN
# 583833                                          NaN
# 583834                                          NaN
#
#         Building_temperature_exceedance  \
# 269217                              0.0
# 269218                              0.0
# 269219                              0.0
# 269220                              0.0
# 269221                              0.0
# ...                                 ...
# 583830                              NaN
# 583831                              NaN
# 583832                              NaN
# 583833                              NaN
# 583834                              NaN
#
#         Building_requirement_temperature_exceedance  Building_heat_demand  \
# 269217                                          NaN                112.11
# 269218                                          NaN                 44.16
# 269219                                          NaN                 46.42
# 269220                                          NaN                 47.03
# 269221                                          NaN                 68.95
# ...                                             ...                   ...
# 583830                                          NaN                   NaN
# 583831                                          NaN                   NaN
# 583832                                          NaN                   NaN
# 583833                                          NaN                   NaN
# 583834                                          NaN                   NaN
#
#         Building_energy_index_with_EMG_standard
# 269217                                      NaN
# 269218                                      NaN
# 269219                                      NaN
# 269220                                      NaN
# 269221                                      NaN
# ...                                         ...
# 583830                                     1.15
# 583831                                     1.15
# 583832                                     1.15
# 583833                                     1.15
# 583834                                     1.28
#
# [314618 rows x 38 columns]

# %% [markdown]
# ## Pompmanstraat (1019W)

# %%
pompman_df = amsterdam_df[amsterdam_df.Building_postcode == '1019WS']

# %%
pompman_df.Building_bag_building_id.values[0] == 363100012065340
# Out:
# True

# %%
spaarn_df = amsterdam_df[amsterdam_df['Building_bag_building_id'] == 363100012117091]

# %%
spaarn_df.Building_house_number
# Out:
# 283899    384.0
# 283900    388.0
# Name: Building_house_number, dtype: float64

# %%
spaarn_df
# Out:
#         Building_admission_date Building_admission_type Building_status  \
# 283899                 20230403             Basisopname        Bestaand
# 283900                 20211126             Basisopname        Bestaand
#
#                      Building_calculation_type  Building_energy_index  \
# 283899  NTA 8800:2022 (basisopname woningbouw)                    NaN
# 283900  NTA 8800:2020 (basisopname woningbouw)                    NaN
#
#        Building_energy_class  Building_energy_label_is_private  \
# 283899                     C                               NaN
# 283900                     A                               NaN
#
#         Building_based_on_reference_building Building_class  \
# 283899                                     0              W
# 283900                                     0              W
#
#         Measurement_valid_until  ...  Building_primary_fossil_energy  \
# 283899                 20330403  ...                          236.55
# 283900                 20311126  ...                          116.91
#
#        Building_requirement_primary_fossil_energy  \
# 283899                                        NaN
# 283900                                        NaN
#
#         Building_primary_fossil_energy_EMG_standard  \
# 283899                                       236.55
# 283900                                       116.91
#
#        Building_share_renewable_energy  \
# 283899                             0.0
# 283900                             0.0
#
#        Building_requirement_share_renewable_energy  \
# 283899                                         NaN
# 283900                                         NaN
#
#        Building_share_renewable_energy_EMG_standard  \
# 283899                                          NaN
# 283900                                          0.0
#
#         Building_temperature_exceedance  \
# 283899                             3.74
# 283900                             2.35
#
#         Building_requirement_temperature_exceedance  Building_heat_demand  \
# 283899                                          NaN                161.85
# 283900                                          NaN                 67.18
#
#         Building_energy_index_with_EMG_standard
# 283899                                      NaN
# 283900                                      NaN
#
# [2 rows x 38 columns]

# %%
konnin_df = df[df['Building_bag_building_id'] == 363100012074933]

# %%
konnin_df
# Out:
#         Building_admission_date Building_admission_type Building_status  \
# 437700                 20240208             Basisopname        Bestaand
# 437706                 20240208             Basisopname        Bestaand
#
#                      Building_calculation_type  Building_energy_index  \
# 437700  NTA 8800:2023 (basisopname woningbouw)                    NaN
# 437706  NTA 8800:2023 (basisopname woningbouw)                    NaN
#
#        Building_energy_class  Building_energy_label_is_private  \
# 437700                   A++                               NaN
# 437706                    A+                               NaN
#
#         Building_based_on_reference_building Building_class  \
# 437700                                     0              W
# 437706                                     0              W
#
#         Measurement_valid_until  ...  Building_primary_fossil_energy  \
# 437700                 20340208  ...                           20.18
# 437706                 20340208  ...                           25.72
#
#        Building_requirement_primary_fossil_energy  \
# 437700                                        NaN
# 437706                                        NaN
#
#         Building_primary_fossil_energy_EMG_standard  \
# 437700                                        73.24
# 437706                                        92.93
#
#        Building_share_renewable_energy  \
# 437700                            75.2
# 437706                            75.1
#
#        Building_requirement_share_renewable_energy  \
# 437700                                         NaN
# 437706                                         NaN
#
#        Building_share_renewable_energy_EMG_standard  \
# 437700                                          NaN
# 437706                                          NaN
#
#         Building_temperature_exceedance  \
# 437700                             1.90
# 437706                             3.49
#
#         Building_requirement_temperature_exceedance  Building_heat_demand  \
# 437700                                          NaN                  46.0
# 437706                                          NaN                  64.0
#
#         Building_energy_index_with_EMG_standard
# 437700                                      NaN
# 437706                                      NaN
#
# [2 rows x 38 columns]

# %%
konnin_df
# Out:
# Empty DataFrame
# Columns: [Building_admission_date, Building_admission_type, Building_status, Building_calculation_type, Building_energy_index, Building_energy_class, Building_energy_label_is_private, Building_based_on_reference_building, Building_class, Measurement_valid_until, Building_registration_date, Building_postcode, Building_house_number, Building_house_letter, Building_house_number_addition, Building_detail_designation, Building_bag_residence_object_id, Building_bag_mooring_place_id, Building_bag_standing_place_id, Building_bag_building_id, Building_type, Building_subtype, Building_project_name, Building_project_object, Building_SBI_code, Building_usable_floor_area_thermal_zone, Building_energy_requirement, Building_requirement_energy_requirement, Building_primary_fossil_energy, Building_requirement_primary_fossil_energy, Building_primary_fossil_energy_EMG_standard, Building_share_renewable_energy, Building_requirement_share_renewable_energy, Building_share_renewable_energy_EMG_standard, Building_temperature_exceedance, Building_requirement_temperature_exceedance, Building_heat_demand, Building_energy_index_with_EMG_standard]
# Index: []
#
# [0 rows x 38 columns]
