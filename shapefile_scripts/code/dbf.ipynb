# %%
import geopandas as gpd

# %%
# Read the .dbf file
file_path = '../data/building-geometry/typology.dbf'
data = gpd.read_file(file_path)

# Plot the data
data.plot()

# Show the plot
import matplotlib.pyplot as plt
plt.show()

# %%
data
# Out:
#      Name STANDARD    YEAR    1ST_USE  1ST_USE_R 2ND_USE  2ND_USE_R 3RD_USE  \
# 0   B1000    SFH_I  2000.0  MULTI_RES        1.0    NONE        0.0    NONE
# 1   B1001    SFH_I  2000.0  MULTI_RES        1.0    NONE        0.0    NONE
# 2   B1002    SFH_I  2000.0  MULTI_RES        1.0    NONE        0.0    NONE
# 3   B1003    SFH_I  2000.0  MULTI_RES        1.0    NONE        0.0    NONE
# 4   B1004    SFH_I  2000.0  MULTI_RES        1.0    NONE        0.0    NONE
# 5   B1005    SFH_I  2000.0  MULTI_RES        1.0    NONE        0.0    NONE
# 6   B1006    SFH_I  2000.0  MULTI_RES        1.0    NONE        0.0    NONE
# 7   B1007    SFH_I  2000.0  MULTI_RES        1.0    NONE        0.0    NONE
# 8   B1008    SFH_I  2000.0     OFFICE        1.0    NONE        0.0    NONE
# 9   B1009    SFH_I  2000.0      HOTEL        1.0    NONE        0.0    NONE
# 10  B1010    SFH_I  2000.0      HOTEL        1.0    NONE        0.0    NONE
# ...
